# %% [markdown]
# # Import Global modules

# %%
import import_ipynb

# %% [markdown]
# # Import User-Defined Functions

# %%
from Project_Functions_Definitions import *
# Out:
# importing Jupyter notebook from Project_Functions_Definitions.ipynb

# %% [markdown]
# # Retrieving_GNSS_data

# %%
data = Read_GNSS_Data("IGS_ALL_DATA_DAILY_OSAH_imputed.csv")

# %% [markdown]
# # Retrieving GNSS_Stations

# %%
ABPO_STATION = Station_Extraction('ABPO',data)
ADIS_STATION = Station_Extraction('ADIS',data)
MAL2_STATION = Station_Extraction('MAL2',data)
NURK_STATION = Station_Extraction('NURK',data)

# %% [markdown]
# ## Moving Average Forecasting-(ABPO)Data is Stationary, no seasonality, no trend

# %%
Moving_Average(ABPO_STATION, 1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
# ...

# %% [markdown]
# ## Moving Average Forecasting(ADIS)-Data is Non-Stationary, with trend

# %%
Moving_Average(ADIS_STATION, 1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
# ...

# %% [markdown]
# ## Moving Average Forecasting(MAL2)-Data is Non-Stationary, no trend but seasonality

# %%
Moving_Average(MAL2_STATION, 1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
# ...

# %% [markdown]
# ## Moving Average Forecasting(NURK)-Data is Stationary, with trend but no seasonality

# %%
Moving_Average(NURK_STATION, 1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
# ...
