# %% [markdown]
# # Import Global modules

# %%
import import_ipynb

# %% [markdown]
# # Import User-Defined Functions

# %%
from Project_Functions_Definitions import *
# Out:
# importing Jupyter notebook from Project_Functions_Definitions.ipynb

# %% [markdown]
# # Retrieving_GNSS_data

# %%
data = Read_GNSS_Data("IGS_ALL_DATA_DAILY_OSAH_imputed.csv")

# %% [markdown]
# # Retrieving GNSS_Stations

# %%
ABPO_STATION = Station_Extraction('ABPO',data)
ADIS_STATION = Station_Extraction('ADIS',data)
MAL2_STATION = Station_Extraction('MAL2',data)
NURK_STATION = Station_Extraction('NURK',data)

# %% [markdown]
# # Autoregressive Forecasting

# %% [markdown]
# ## Autoregressive Forecasting at ABPO-Data is Stationary no trend no seasonality

# %%
Autoregressive_Forecasting(ABPO_STATION,1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              AutoReg Model Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                     AutoReg(1)   Log Likelihood                6207.537
#  Method:               Conditional MLE   S.D. of innovations              0.019
# ...

# %% [markdown]
# ## Autoregressive Forecasting at ADIS-Data is Non-Stationary with increasing Trend

# %%
Autoregressive_Forecasting(ADIS_STATION,1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              AutoReg Model Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                     AutoReg(1)   Log Likelihood                7379.043
#  Method:               Conditional MLE   S.D. of innovations              0.011
# ...

# %% [markdown]
# ## Autoregressive Forecasting at MAL2-Data is Non-Stationary with no Trend but seasonality

# %%
Autoregressive_Forecasting(MAL2_STATION,1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              AutoReg Model Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                     AutoReg(1)   Log Likelihood                6198.370
#  Method:               Conditional MLE   S.D. of innovations              0.019
# ...

# %% [markdown]
# ## Autoregressive Forecasting at NURK-Data is Stationary with Trend but no seasonality

# %%
Autoregressive_Forecasting(NURK_STATION,1)
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                              AutoReg Model Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                     AutoReg(1)   Log Likelihood                6662.360
#  Method:               Conditional MLE   S.D. of innovations              0.015
# ...

# %%
# order = (1, 0, 1)                # (AR, I, MA) order
# seasonal_order = (1, 1, 1, 365)   # (Seasonal AR, Seasonal I, Seasonal MA, Seasonal Period) order (assuming 30 days in a month)
# sarima_train_data = ABPO_STATION.iloc[:-500]
# # Create and fit the SARIMA model
# sarima_model = sm.tsa.SARIMAX(sarima_train_data['ZTD_igs'], order=order, seasonal_order=seasonal_order)
# sarima_model_fit = sarima_model.fit()

# # Generate forecasts
# start = 2422
# end = 2922
# forecast = sarima_model_fit.predict(start=start, end=end,dynamic = True)

# # Print the forecasted values
# sarima_model_fit.summary()

# %% [markdown]
# The Autoregressive has more accuracy forecasting than moving averegage in terms of Bayesian information criteria.
