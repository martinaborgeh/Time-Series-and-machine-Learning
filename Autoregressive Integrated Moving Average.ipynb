# %% [markdown]
# # Import Global modules

# %%
import import_ipynb

# %% [markdown]
# # Import User-Defined Functions

# %%
from Project_Functions_Definitions import *
# Out:
# importing Jupyter notebook from Project_Functions_Definitions.ipynb

# %% [markdown]
# # Retrieving_GNSS_data

# %%
data = Read_GNSS_Data("IGS_ALL_DATA_DAILY_OSAH_imputed.csv")

# %% [markdown]
# # Retrieving GNSS_Stations

# %%
ABPO_STATION = Station_Extraction('ABPO',data)
ADIS_STATION = Station_Extraction('ADIS',data)
MAL2_STATION = Station_Extraction('MAL2',data)
NURK_STATION = Station_Extraction('NURK',data)

# %% [markdown]
# ## ARIMA Forecasting-(ABPO)Data is Stationary, no seasonality, no trend

# %%
Arima_Forecasting(ABPO_STATION,(1,0,1))
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                                 SARIMAX Results
# ...

# %% [markdown]
# # ARIMA Forecasting-(ADIS)Data is NON-Stationary,with  trend

# %%
first_detrend = Remove_Trend_or_Seasonal(ADIS_STATION,'T')
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# date
# 2015-01-02   -0.004565
# 2015-01-03    0.000374
# 2015-01-04    0.015795
# 2015-01-05    0.017392
# 2015-01-06    0.009969
#                 ...
# 2022-12-27    0.006284
# 2022-12-28   -0.002556
# 2022-12-29   -0.002556
# 2022-12-30   -0.007208
# 2022-12-31    0.003604
# Name: ZTD_igs, Length: 2921, dtype: float64
# Trend: no trend
# H: False
# p-value: 0.059862717234388185
# Z: -1.8818033763067818
# ADF Statistic: -16.72955251169302
# p-value: 1.38679809648731e-29
# Critical Values:
# 	1%: -3.4326069302485953
# 	5%: -2.8625371602624137
# 	10%: -2.567300816765755

# %%
Arima_Forecasting(ADIS_STATION,(1,1,1))
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                                 SARIMAX Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                 ARIMA(1, 1, 1)   Log Likelihood                7444.198
# ...

# %% [markdown]
# # ARIMA Forecasting-(MAL2)Data is NON-Stationary,no  trend but seasonal

# %%
Arima_Forecasting(MAL2_STATION,(1,0,1))
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                                 SARIMAX Results
# ...

# %% [markdown]
# # ARIMA Forecasting-(NURK)Data is Stationary,with trend no seasonal

# %%
first_detrend = Remove_Trend_or_Seasonal(NURK_STATION,'T')
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# date
# 2015-01-02   -0.006013
# 2015-01-03    0.000000
# 2015-01-04   -0.006543
# 2015-01-05    0.006543
# 2015-01-06    0.000000
#                 ...
# 2022-12-27   -0.001339
# 2022-12-28    0.000000
# 2022-12-29   -0.034686
# 2022-12-30   -0.020076
# 2022-12-31    0.000000
# Name: ZTD_igs, Length: 2921, dtype: float64
# Trend: no trend
# H: False
# p-value: 0.8478862375870184
# Z: 0.19181612754676403
# ADF Statistic: -17.022388063463243
# p-value: 8.438644896355145e-30
# Critical Values:
# 	1%: -3.432606151575025
# 	5%: -2.8625368163579603
# 	10%: -2.567300633673491

# %%
Arima_Forecasting(NURK_STATION,(1,1,1))
# Out:
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\Martin Aborgeh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# (<class 'statsmodels.iolib.summary.Summary'>
#  """
#                                 SARIMAX Results
# ...
#  Dep. Variable:                ZTD_igs   No. Observations:                 2422
#  Model:                 ARIMA(1, 1, 1)   Log Likelihood                6676.656
# ...
